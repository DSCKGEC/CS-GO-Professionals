# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
import requests
import json
from pandas.io.json import json_normalize
#Reading data from json directly and setting max limit to 10000 (Note there are only 100 values )
url = "https://www.playerauctions.com/api/csgo/ranking?pageindex=1&filter=top&sort=win&limit=10000"

response = requests.get(url)
data = json.loads(response.text)
df1=json_normalize(data[1])
df1
# Out:
# C:\Users\CHIRAG LALWANI\AppData\Local\Temp\ipykernel_20592\4184346398.py:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df1=json_normalize(data[1])
#               steamID       personaName loccountryCode englishName  \
# 0   76561198058315763         อาจารย์กบ             th    Thailand
# 1   76561198797898200             arvin             jp       Japan
# 2   76561198886796378            Dax272             jp       Japan
# 3   76561198066844229      feelsgoodman             id   Indonesia
# 4   76561198183642251     Vader[TR] 🚀🚀🚀             tr      Turkey
# ..                ...               ...            ...         ...
# 92  76561198327473312             0czer             de     Germany
# 93  76561198190268759             Soddo             no      Norway
# 94  76561198177295662        Cardinal90             ru         RUS
# 95  76561198014126198             NEMEC             ua     Ukraine
# ...

# %%
#This is data of top 3 players
df2=json_normalize(data[0])
df2
# Out:
# C:\Users\CHIRAG LALWANI\AppData\Local\Temp\ipykernel_20592\79137350.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df2=json_normalize(data[0])
#              steamID  personaName loccountryCode englishName  \
# 0  76561198087760553        PUTIN             ru         RUS
# 1  76561198122166367     фотограф             ae         ARE
# 2  76561197978680703  lpb is real             br      Brazil
#
#                                               avatar  state  level  \
# 0  https://steamcdn-a.akamaihd.net/steamcommunity...      1      1
# 1  https://steamcdn-a.akamaihd.net/steamcommunity...      1      1
# 2  https://steamcdn-a.akamaihd.net/steamcommunity...      1      1
#
#    visibilityState    kdr     win  ... enemiesTasered aimingSnipersKilled  \
# 0                0  10.10  100.00  ...    987,897,879         978,979,083
# 1                0  10.03   99.99  ...             14         100,007,059
# ...

# %%
df = pd.concat([df2, df1], axis=0)

# %%
df
# Out:
#               steamID       personaName loccountryCode englishName  \
# 0   76561198087760553             PUTIN             ru         RUS
# 1   76561198122166367          фотограф             ae         ARE
# 2   76561197978680703       lpb is real             br      Brazil
# 0   76561198058315763         อาจารย์กบ             th    Thailand
# 1   76561198797898200             arvin             jp       Japan
# ..                ...               ...            ...         ...
# 92  76561198327473312             0czer             de     Germany
# 93  76561198190268759             Soddo             no      Norway
# 94  76561198177295662        Cardinal90             ru         RUS
# 95  76561198014126198             NEMEC             ua     Ukraine
# 96  76561198308830071  Пынгвин csgo.run             ru         RUS
#
#                                                avatar  state  level  \
# 0   https://steamcdn-a.akamaihd.net/steamcommunity...      1      1
# ...

# %%
df.columns
# Out:
# Index(['steamID', 'personaName', 'loccountryCode', 'englishName', 'avatar',
#        'state', 'level', 'visibilityState', 'kdr', 'win', 'headShot',
#        'accuracy', 'timePlayed', 'roundsPlayed', 'roundsWon', 'headShots',
#        'shotsHit', 'shotsFired', 'matchesPlayed', 'kills', 'deaths',
#        'moneyEarned', 'pistolRoundsWon', 'killedKnifeFight',
#        'killsEnemyWeapon', 'bombsSet', 'totalDamage', 'enemiesTasered',
#        'aimingSnipersKilled', 'mvPs', 'bombsDefused', 'totalScore',
#        'windowsBroken', 'blindedEnemiesKilled', 'weaponsToTeam',
#        'hostagesRescued', 'ranking'],
#       dtype='object')

# %%
df.rename(columns={'englishName': 'Country'}, inplace=True)
df.drop(columns=['avatar','windowsBroken','weaponsToTeam'],inplace=True)

# %%
df.to_csv('CSGO_2023_players.csv')
