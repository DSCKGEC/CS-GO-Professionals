# %%
#importing libraries 
import dash
from dash import dcc
from dash import html

import plotly.graph_objs as pgo
import numpy as np
import pandas as pd
from dash.dependencies import Input, Output, State

# %%
#loading data acc. to file located in my local system
stats=pd.read_csv("CSGO Player Dataset(FE).csv")

# %%
stats
# Out:
#      Unnamed: 0     Name                       Teams Played In  \
# 0             0    ZywOo                     'Vitality', 'aAa'
# 1             1   s1mple                       'Natus Vincere'
# 2             2    sh1ro         'Gambit Youngsters', 'Gambit'
# 3             3     deko                                '1WIN'
# 4             4   saffee                       'FURIA', 'paiN'
# ..          ...      ...                                   ...
# 799         799    B1ad3                            'FlipSid3'
# 800         800  netrick  'AGF', 'unknown', 'LPSP', 'Forcebuy'
# 801         801   HUNDEN          'Tricked', 'ALTERNATE aTTaX'
# 802         802   RuFire      'SG.pro', '5balls', 'VP.Prodigy'
# 803         803    OCEAN            'subtLe', 'SKDC', 'Splyce'
#
#      Number of Maps Played  Number of Rounds Played  Kill Death Difference  \
# 0                      985                    25890                   5999
# 1                     1544                    40788                   8916
# 2                      853                    22639                   5372
# 3                      382                    10313                   2270
# 4                      374                     9873                   1936
# ..                     ...                      ...                    ...
# 799                    899                    23232                  -3408
# 800                    455                    11976                  -1736
# 801                   1578                    41153                  -6238
# 802                    384                    10185                  -1927
# 803                    410                    10602                  -1962
#
#      K/D Ratio  HLTV Rating  Total Deaths  Total Kills
# 0         1.38         1.27       15786.0      21785.0
# 1         1.34         1.25       26223.0      35139.0
# 2         1.45         1.22       11937.0      17309.0
# 3         1.38         1.22        5973.0       8243.0
# 4         1.32         1.21        6049.0       7985.0
# ..         ...          ...           ...          ...
# 799       0.80         0.83       17040.0      13632.0
# 800       0.80         0.82        8680.0       6944.0
# 801       0.78         0.81       28354.0      22116.0
# 802       0.74         0.78        7411.0       5484.0
# 803       0.74         0.77        7546.0       5584.0
#
# [804 rows x 10 columns]

# %%
stats.corr()
# Out:
#                          Unnamed: 0  Number of Maps Played  \
# Unnamed: 0                 1.000000              -0.169791
# Number of Maps Played     -0.169791               1.000000
# Number of Rounds Played   -0.167271               0.999568
# Kill Death Difference     -0.858660               0.324522
# K/D Ratio                 -0.937348               0.168103
# HLTV Rating               -0.961626               0.163080
# Total Deaths              -0.125885               0.963995
# Total Kills               -0.283661               0.960797
#
#                          Number of Rounds Played  Kill Death Difference  \
# Unnamed: 0                             -0.167271              -0.858660
# Number of Maps Played                   0.999568               0.324522
# Number of Rounds Played                 1.000000               0.322583
# Kill Death Difference                   0.322583               1.000000
# K/D Ratio                               0.166044               0.895239
# HLTV Rating                             0.161062               0.883596
# Total Deaths                            0.964295               0.263219
# Total Kills                             0.960698               0.439026
#
#                          K/D Ratio  HLTV Rating  Total Deaths  Total Kills
# Unnamed: 0               -0.937348    -0.961626     -0.125885    -0.283661
# Number of Maps Played     0.168103     0.163080      0.963995     0.960797
# Number of Rounds Played   0.166044     0.161062      0.964295     0.960698
# Kill Death Difference     0.895239     0.883596      0.263219     0.439026
# K/D Ratio                 1.000000     0.976082      0.106403     0.272540
# HLTV Rating               0.976082     1.000000      0.116236     0.279564
# Total Deaths              0.106403     0.116236      1.000000     0.982351
# Total Kills               0.272540     0.279564      0.982351     1.000000

# %%
stats=stats.drop('Unnamed: 0',axis=1)

# %%
#names of players to be displayed on x axis
player_names=list(stats["Name"])

# %%
player_names
# Out:
# ['ZywOo',
#  's1mple',
#  'sh1ro',
#  'deko',
#  'saffee',
#  'Kaze',
#  'degster',
#  'smooya',
#  'sterling',
#  'XANTARES',
#  'torzsi',
#  'DANK1NG',
#  'device',
#  'SENSEi',
#  'NiKo',
#  'BnTeT',
#  'coldzera',
#  'XigN',
#  'blameF',
#  'Sico',
#  'KSCERATO',
#  'Benkai',
#  'XELLOW',
#  'Jame',
#  'Texta',
#  'mhL',
#  'El1an',
#  'oskar',
#  'kennyS',
#  'frozen',
#  'mantuu',
#  'huNter-',
#  'yuurih',
#  'Freeman',
#  'erkaSt',
#  'chelleos',
#  'vsm',
#  'woxic',
#  'INS',
#  'liTTle',
#  'ropz',
#  'dream3r',
#  'kNgV-',
#  'Jamppi',
#  'wrath',
#  'xsepower',
#  'PTC',
#  'GuardiaN',
#  'splashske',
#  'Twistzz',
#  'oSee',
#  'NEOFRAG',
#  'dgt',
#  'ottoNd',
#  'zorte',
#  'FREDDyFROG',
#  'Brehze',
#  'TenZ',
#  'f0rest',
#  'CeRq',
#  'Infinite',
#  'Olivia',
#  'poizon',
#  'mertz',
#  'ekul',
#  'WARDELL',
#  'dumau',
#  'nawwk',
#  'swag',
#  'HEN1',
#  'mir',
#  'h4rn',
#  'aliStair',
#  'Ax1Le',
#  'Spinx',
#  'moose',
#  'nython',
#  'Calyx',
#  'xccurate',
#  'mixwell',
#  'PwnAlone',
#  'hades',
#  'allu',
#  'electroNic',
#  'lollipop21k',
#  'syrsoN',
#  'GeT_RiGhT',
#  'floppy',
#  'JUGi',
#  'dexter',
#  'Farlig',
#  'cynic',
#  'Cooper',
#  'gas',
#  'Sonic',
#  'zehN',
#  'JOTA',
#  'ZOREE',
#  'NAF',
#  'ryx',
#  'mezii',
#  'BL1TZ',
#  'biguzera',
#  'ScreaM',
#  'dennyslaw',
#  'EliGE',
#  'HaZR',
#  'faveN',
#  'nex',
#  'fer',
#  'valde',
#  'k0nfig',
#  'nukkye',
#  'Attacker',
#  'dupreeh',
#  'Magisk',
#  'exit',
#  'Savage',
#  'Machinegun',
#  'DJOXiC',
#  'Detrony',
#  'Summer',
#  'junior',
#  'keev',
#  'felps',
#  'draken',
#  'sergej',
#  'Hatz',
#  'pz',
#  'ShahZaM',
#  'jayzaR',
#  'MICHU',
#  'Ryxxo',
#  'FL1T',
#  'hAdji',
#  'Rickeh',
#  'slaxz-',
#  'ptr',
#  'Impulse',
#  'nicoodoz',
#  'dapr',
#  'YEKINDAR',
#  'NaToSaphiX',
#  'meyern',
#  'Liazz',
#  'iDISBALANCE',
#  'autimatic',
#  'shox',
#  'trk',
#  'fejtZ',
#  'jks',
#  'dycha',
#  'smike',
#  'NikoM',
#  'hallzerk',
#  'xand',
#  'paz',
#  'CRUC1AL',
#  'InfrequeNt',
#  'EspiranTo',
#  'boltz',
#  'HObbit',
#  'WorldEdit',
#  'QKA',
#  'hardzao',
#  'fame',
#  'somebody',
#  'broky',
#  'FalleN',
#  'Brollan',
#  'anarkez',
#  'shroud',
#  'Pimp',
#  'shz',
#  'DD',
#  'NikkeZ',
#  'chelo',
#  'snatchie',
#  'zhokiNg',
#  'b1t',
#  'roeJ',
#  'ofnu',
#  'AnJ',
#  'Ethan',
#  'Happy',
#  'acoR',
#  'flying',
#  'SHiPZ',
#  'COLDYY1',
#  'SLOWLY',
#  'Valiance',
#  'b4rtiN',
#  'Skadoodle',
#  'pancc',
#  'Maka',
#  'koosta',
#  'suNny',
#  'tucks',
#  'TOR',
#  'olofmeister',
#  'malbsMd',
#  'nexa',
#  'Gratisfaction',
#  'KEi',
#  'REDSTAR',
#  'Rainwaker',
#  'rallen',
#  'bottle',
#  'ISSAA',
#  'tabseN',
#  'zeph',
#  'Sobol',
#  'iM',
#  'JW',
#  'Ramz1kBO$$',
#  'HZ',
#  'cajunb',
#  'mou',
#  'sdy',
#  'KRIMZ',
#  'Marcelious',
#  'TeSeS',
#  'yay',
#  'Grim',
#  'Qikert',
#  'stavn',
#  'juanflatroo',
#  'SicK',
#  'NEEX',
#  'Aerial',
#  'loWel',
#  'Flarich',
#  'raafa',
#  'Zellsis',
#  'WolfY',
#  'flusha',
#  'rommi',
#  'cadiaN',
#  'malta',
#  'refrezh',
#  'MarKE',
#  'Swahn',
#  'Kjaerbye',
#  'FASHR',
#  'kabal',
#  'afro',
#  'n0rb3r7',
#  'DavCost',
#  'Bwills',
#  'zewsy',
#  'STOMP',
#  'aumaN',
#  'jkaem',
#  'Snakes',
#  'Hiko',
#  'Geniuss',
#  'Snax',
#  'KHTEX',
#  'motm',
#  'Lucky',
#  'HSK',
#  'Bubzkji',
#  'eraa',
#  'twist',
#  'ANDROID',
#  'imoRR',
#  'LOVEYY',
#  'buster',
#  'Lucky',
#  'Davidp',
#  'tb',
#  'TRAVIS',
#  'dobu',
#  'dEE',
#  'tarik',
#  'Kntz',
#  'rAge',
#  'REZ',
#  'JUST',
#  'Maden',
#  'NK4Y',
#  'USTILO',
#  'land1n',
#  'Subroza',
#  'F1KU',
#  'sjuush',
#  'max',
#  'Lucaozy',
#  'DannyG',
#  'yam',
#  'fnx',
#  'juho',
#  'KENSI',
#  'JonY BoY',
#  'alex',
#  'Relaxa',
#  'fleav',
#  'znajder',
#  'DEV7L',
#  'AiyvaN',
#  'rain',
#  'DiMKE',
#  'captainMo',
#  'phzy',
#  'Thomas',
#  'glowiing',
#  'stfN',
#  'Patsi',
#  'Spargo',
#  'RCF',
#  'kressy',
#  'Patitek',
#  'shuadapai',
#  'aizy',
#  'FrostMisty',
#  'Forester',
#  'fl0m',
#  'RIKO',
#  'dennis',
#  'food',
#  'flamie',
#  'cxzi',
#  'pashaBiceps',
#  'Krad',
#  'hoody',
#  'FaNg',
#  'Maluk3',
#  'CyberFocus',
#  'kai',
#  'sLowi',
#  'smiley',
#  'HexT',
#  'niko',
#  'AMANEK',
#  'dragonfly',
#  'szejn',
#  'kolor',
#  'JDC',
#  'HS',
#  'NBK-',
#  'jdm64',
#  'Tuurtle',
#  'DeStiNy',
#  'bondik',
#  'MonttY',
#  'FANAT ROCKA',
#  'disco doplan',
#  'Nico',
#  'mouz',
#  'qqGOD',
#  'MoeycQ',
#  'Spongey',
#  'v1c7oR',
#  'NENO',
#  'Xyp9x',
#  'b0denmaster',
#  'spaze',
#  'apEX',
#  'Plopski',
#  'mar',
#  'Ace',
#  'Markoś',
#  'dimasick',
#  'yel',
#  'iDk',
#  'Goofy',
#  'queztone',
#  'ROBO',
#  'steel',
#  'TENZKI',
#  'fr0slev',
#  'LETN1',
#  'fox',
#  'n0thing',
#  'SKYTTEN',
#  'roseau',
#  'roca',
#  'flickz',
#  'es3tag',
#  'xCeeD',
#  'chrisJ',
#  'aproto',
#  'Nodios',
#  'Jyo',
#  'bedonka',
#  'Zyphon',
#  'Voltage',
#  'delboNi',
#  'Kylar',
#  'byali',
#  'tatazin',
#  'GruBy',
#  'desi',
#  'shokz',
#  'b0RUP',
#  'HUGHMUNGUS',
#  'PlesseN',
#  'kreaz',
#  'Maikelele',
#  'Lekr0',
#  'mitch',
#  'SHOCK',
#  'hampus',
#  'jedqr',
#  'Noobster',
#  'Viva',
#  'Swisher',
#  'obj',
#  '1962',
#  'spyleadeR',
#  'ap0c',
#  'EasTor',
#  'stadodo',
#  'arT',
#  'mirbit',
#  'Friis',
#  'grux',
#  'dazzLe',
#  'ayaya',
#  'reatz',
#  'Stewie2K',
#  'kalinka',
#  'Jinxx',
#  'siuhy',
#  'to1nou',
#  'DickStacy',
#  'jR',
#  'zqkS',
#  'DESPE',
#  'kioShiMa',
#  'speed4k',
#  'FugLy',
#  'emagine',
#  'Polt',
#  'Nifty',
#  'Tsogoo',
#  'MINISE',
#  'waterfaLLZ',
#  'pounh',
#  'Zero',
#  'innocent',
#  'Relyks',
#  'fenvicious',
#  'glace',
#  'Oderus',
#  '1uke',
#  'Edward',
#  'leo_drk',
#  'R0b3n',
#  'Lack1',
#  'SIXER',
#  'hazed',
#  'xiaosaGe',
#  'ALLE',
#  'nitr0',
#  'kenzor',
#  'Djoko',
#  'almazer',
#  'cbbk',
#  'dzt',
#  'KILLDREAM',
#  'Basso',
#  'RoLEX',
#  'zeff',
#  'cromen',
#  'SZPERO',
#  'adreN',
#  'supra',
#  'xseveN',
#  'mopoz',
#  'void',
#  'pyth',
#  'mds',
#  'MODDII',
#  'ImpressioN',
#  'cam',
#  'freakazoid',
#  'peet',
#  'STYKO',
#  'pecks',
#  'Cabbi',
#  'Noktse',
#  'Liki',
#  'magixx',
#  'truth',
#  'vice',
#  'Bååten',
#  'Jerry',
#  'xelos',
#  'uli',
#  'reversive',
#  'freddieb',
#  'SEMPHIS',
#  'dephh',
#  'MUTiRiS',
#  'DeathZz',
#  'Vegi',
#  'robiin',
#  'YDNA',
#  'gMd',
#  'ALEX',
#  'notaN',
#  'markeloff',
#  'VINI',
#  'Puls3',
#  'neptune',
#  'rbz',
#  'BENDJI',
#  'dukefissura',
#  'jaxi',
#  'BARBARR',
#  'realz1n',
#  'kory',
#  'Dima',
#  'JIaYm',
#  'ANGE1',
#  'kaboose',
#  'bubble',
#  'morelz',
#  'facecrack',
#  'Drone',
#  'krii',
#  'djay',
#  'k1to',
#  'sXe',
#  'Dosia',
#  'vanity',
#  'JACKZ',
#  'fitch',
#  'gade',
#  'SAGGERTON',
#  'larsen',
#  'jabbi',
#  'Lukki',
#  'rmn',
#  'pesadelo',
#  'AZR',
#  'ryotzz',
#  'J1rah',
#  'gla1ve',
#  'DAVEY',
#  'Jonji',
#  'Furlan',
#  'bodyy',
#  'stellar',
#  'Xizt',
#  'Daffu',
#  'RUBINO',
#  'AdreN',
#  'apocdud',
#  'bew',
#  'Perfecto',
#  'ryann',
#  'Zix',
#  'chop',
#  'NEKIZ',
#  'DeadFox',
#  'NickelBack',
#  'isak',
#  'zende',
#  'bq',
#  'Spiidi',
#  'anger',
#  'WOOD7',
#  'Llamas',
#  'doto',
#  'raalz',
#  'tifa',
#  'kwezz',
#  'wiz',
#  'BIT',
#  'SHOOWTiME',
#  'syken',
#  'sinnopsyy',
#  'Radifaction',
#  'jnt',
#  'prt',
#  'niki1',
#  'BURNRUOk',
#  'Boombl4',
#  'Sergiz',
#  'PERCY',
#  'blocker',
#  'RUSH',
#  'Fadey',
#  'SPELLAN',
#  'DeStRoYeR',
#  'RpK',
#  'mono',
#  'ZEDKO',
#  'FinigaN',
#  'leman',
#  'propleh',
#  'jmqa',
#  'Keoz',
#  'seb',
#  'RuStY',
#  'oskarish',
#  'Queenix',
#  'kUcheR',
#  'Marek',
#  'stk',
#  'ELUSIVE',
#  'ice',
#  'SOKER',
#  'Drea3er',
#  'PKL',
#  'DEVIL',
#  'seized',
#  'MAIROLLS',
#  'gabesson',
#  'Sapec',
#  'Mayker',
#  'TMB',
#  'The eLiVe',
#  'KHRN',
#  'Leaf',
#  'starix',
#  'chopper',
#  'reltuC',
#  'Surreal',
#  'phr',
#  'Hyper',
#  'LUCAS1',
#  'Maniac',
#  'SmithZz',
#  'nafany',
#  'ProbLeM',
#  'kaper',
#  'Walco',
#  'SEMINTE',
#  'SADDYX',
#  'maeVe',
#  'Kairi',
#  'Tommy',
#  'HOLMES',
#  'stanislaw',
#  'w1nt3r',
#  'Aleksib',
#  'bodito',
#  'nosraC',
#  'xms',
#  '0i',
#  'JazzPimp',
#  'Uber',
#  'tiziaN',
#  'misutaaa',
#  'glow',
#  'Kvik',
#  'Kristou',
#  'Snappi',
#  'expro',
#  'MAJ3R',
#  'nbl',
#  'LOGAN',
#  'smF',
#  'YJ',
#  'kinqie',
#  'tahsiN',
#  'maNkz',
#  'NEO',
#  'ponczek',
#  'denis',
#  'alexRr',
#  'dezon',
#  'dumz',
#  'RZU',
#  'friberg',
#  'caike',
#  'H4RR3',
#  'JT',
#  'TaZ',
#  'steel',
#  'devoduvek',
#  'Console',
#  'CONNOR93',
#  'soju_j',
#  'PR1mE',
#  'dERZKIY',
#  'darko',
#  'KrizzeN',
#  'Grusarn',
#  'AcilioN',
#  'RAiLWAY',
#  'beastik',
#  'flashie',
#  'strux1',
#  'ecfN',
#  'oxygeN',
#  'Karsa',
#  'arvid',
#  'Inzta',
#  'Rock1nG',
#  'uNdo',
#  'vSa',
#  'Fifflaren',
#  'boX',
#  'kzy',
#  'TOAO',
#  'SileNt',
#  'Twixie',
#  'tonyblack',
#  'BRACE',
#  'rafftu',
#  'arch',
#  'Sidney',
#  'interz',
#  'EXUS',
#  'RIZZZ',
#  'LOMME',
#  'Polly',
#  'Ex6TenZ',
#  'ub1que',
#  'Noisia',
#  'tutehen',
#  'ngiN',
#  'forget',
#  'Shakezullah',
#  'neaLaN',
#  'repo',
#  'DANZ',
#  'emi',
#  'Duplicate',
#  'hutji',
#  'crisby',
#  'matty',
#  'mynio',
#  'SkulL',
#  'quix',
#  'ztr',
#  'kiR',
#  'TACO',
#  'aVN',
#  'S0tF1k',
#  'hitMouse',
#  'arki',
#  'Xp3',
#  'sorrow',
#  'pNshr',
#  'MSL',
#  'SANJI',
#  'akez',
#  'ncl',
#  'Luz',
#  'Zeus',
#  'nak',
#  'arya',
#  'Dav',
#  'karrigan',
#  'pietola',
#  'svyat',
#  'BTN',
#  'xartE',
#  'tecek',
#  'LEGIJA',
#  'roman',
#  'Shara',
#  'wayLander',
#  'BONA',
#  'sAw',
#  'kRYSTAL',
#  'MiGHTYMAX',
#  'ben1337',
#  'crush',
#  'balblna',
#  'sycrone',
#  'nkl',
#  'hooch',
#  'Golden',
#  'lunAtic',
#  'Adam9130',
#  'FNS',
#  'spiker',
#  'JiNKZ',
#  'MAiNLiNE',
#  'Psycho',
#  'pronax',
#  'Polen',
#  'ScrunK',
#  'Lambert',
#  'LeX',
#  'torben',
#  'JD',
#  'seang@res',
#  'daps',
#  'advent',
#  'flowsicK',
#  'BERRY',
#  'birdfromsky',
#  'nawrot',
#  'HooXi',
#  'def',
#  'djL',
#  'Devilwalk',
#  'Twista',
#  'gob b',
#  'Slemmy',
#  'SolEk',
#  'PASHANOJ',
#  'B1ad3',
#  'netrick',
#  'HUNDEN',
#  'RuFire',
#  'OCEAN']

# %%
#stats of players to be displayed on y axis 
player_stats=list(stats.columns)

# %%
player_stats
# Out:
# ['Name',
#  'Teams Played In',
#  'Number of Maps Played',
#  'Number of Rounds Played',
#  'Kill Death Difference',
#  'K/D Ratio',
#  'HLTV Rating',
#  'Total Deaths',
#  'Total Kills']

# %%
app=dash.Dash()

    
    
app.layout=html.Div([
    
    				html.H1('Player performance comparision dashboard',style={'margin-top':'40px'}),
    
    				html.Div([html.Div([html.H2('Enter the names of players:',style={'paddingRight':'30px','marginLeft':'25px'})]),
    				#this dropdown wil let you choose multiple players name at a time 
                    html.Div([dcc.Dropdown(id='names',
                                        options=[{'label': player, 'value': player} for player in player_names],
                                        value=player_names[0],
                                        multi=True)],style={'verticalAlign':'top','width':'400px','marginLeft':'25px','box-sizing': 'border-box'})],style={'display':'inline-block'}),
    
  
           
           html.Div([html.Div([html.H2("Select the stat :")],style={'paddingRight':'40px','marginLeft':'25px'}),
         #this dropdown will let you choose the stats on which you want to compare the players you already choosen from pevious dropdown            
   		html.Div([dcc.Dropdown(
        id="stats",
        options=[{'label': player, 'value': player} for player in player_stats],
        value=player_stats[0],
        clearable=False
    )],style={'width':'270px','marginLeft':'25px','box-sizing': 'border-box'})],style={'display':'inline-block','marginLeft':'70px'}),
  #upon clicking this submit button bar graph will be ploted 
  html.Div([html.Button(
        id='submit-button',n_clicks=0,children='Submit',style={'fontSize':24,'marginLeft':'670px','margin-top':'40px'})],style={'width':'270px','marginLeft':'25px','box-sizing': 'border-box'}), 
   
   dcc.Graph(id="graph"),
                
           
    
])


@app.callback(
    Output('graph', 'figure'), 
    [Input('submit-button', 'n_clicks')],
    [State('names','value'),
     State('stats','value')])
def compare_stats(n_clicks,x_value,y_value):
    
    trace_list = []
    for i in range(len(x_value)):
        trace = pgo.Bar(
            x=[x_value[i]],
            y=[stats.loc[stats['Name'] == x_value[i], y_value].values[0]],
            name=str(x_value[i])
        )
        trace_list.append(trace)
    data=trace_list
    layout=pgo.Layout(title="Stats Comparison ",barmode='group',xaxis=dict(title="Name of Players "),yaxis=dict(title="Basis of comparison"))
    fig=pgo.Figure(data,layout)
    return fig



if __name__=='__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [07/Mar/2023 12:50:56] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 12:51:00] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 12:51:00] "GET /_dash-dependencies HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\admin\AppData\Local\Temp\ipykernel_7472\1167219928.py", line 48, in compare_stats
#     y=[stats.loc[stats['Name'] == x_value[i], y_value].values[0]],
# IndexError: index 0 is out of bounds for axis 0 with size 0
# 127.0.0.1 - - [07/Mar/2023 12:51:01] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [07/Mar/2023 12:51:01] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 12:51:01] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 12:51:01] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 12:51:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:01:45] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:01:47] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:01:47] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:01:48] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:01:48] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:01:48] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\admin\AppData\Local\Temp\ipykernel_7472\1167219928.py", line 48, in compare_stats
#     y=[stats.loc[stats['Name'] == x_value[i], y_value].values[0]],
# IndexError: index 0 is out of bounds for axis 0 with size 0
# 127.0.0.1 - - [07/Mar/2023 13:01:49] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [07/Mar/2023 13:05:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:05:55] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:05:55] "GET /_dash-dependencies HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\admin\AppData\Local\Temp\ipykernel_7472\1167219928.py", line 48, in compare_stats
#     y=[stats.loc[stats['Name'] == x_value[i], y_value].values[0]],
# IndexError: index 0 is out of bounds for axis 0 with size 0
# 127.0.0.1 - - [07/Mar/2023 13:05:56] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [07/Mar/2023 13:05:57] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:05:57] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:05:57] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:07:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:11:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:11:51] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:11:51] "GET /_dash-dependencies HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\admin\AppData\Local\Temp\ipykernel_7472\1167219928.py", line 48, in compare_stats
#     y=[stats.loc[stats['Name'] == x_value[i], y_value].values[0]],
# IndexError: index 0 is out of bounds for axis 0 with size 0
# 127.0.0.1 - - [07/Mar/2023 13:11:52] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [07/Mar/2023 13:11:52] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:11:52] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:11:52] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:12:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:12:50] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:12:50] "GET /_dash-dependencies HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\admin\AppData\Local\Temp\ipykernel_7472\1167219928.py", line 48, in compare_stats
#     y=[stats.loc[stats['Name'] == x_value[i], y_value].values[0]],
# IndexError: index 0 is out of bounds for axis 0 with size 0
# 127.0.0.1 - - [07/Mar/2023 13:12:50] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [07/Mar/2023 13:12:50] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:12:51] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:12:51] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:13:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:13:35] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:13:35] "GET /_dash-dependencies HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\admin\AppData\Local\Temp\ipykernel_7472\1167219928.py", line 48, in compare_stats
#     y=[stats.loc[stats['Name'] == x_value[i], y_value].values[0]],
# IndexError: index 0 is out of bounds for axis 0 with size 0
# 127.0.0.1 - - [07/Mar/2023 13:13:35] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [07/Mar/2023 13:13:36] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:13:36] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:13:36] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:14:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:14:02] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:14:03] "GET /_dash-dependencies HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\admin\AppData\Local\Temp\ipykernel_7472\1167219928.py", line 48, in compare_stats
#     y=[stats.loc[stats['Name'] == x_value[i], y_value].values[0]],
# IndexError: index 0 is out of bounds for axis 0 with size 0
# 127.0.0.1 - - [07/Mar/2023 13:14:03] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [07/Mar/2023 13:14:03] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:14:04] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:14:04] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2023 13:15:02] "POST /_dash-update-component HTTP/1.1" 200 -
