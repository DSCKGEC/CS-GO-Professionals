# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Feature engineering is the process of selecting, transforming, extracting, combining, and manipulating raw data to generate the desired variables for analysis or predictive modeling. It is a crucial step in developing a machine learning model.

# %% [markdown]
# #### Importing required libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Loading the dataset into a Dataframe

# %%
df = pd.read_csv('CSGO Player Dataset(Raw).csv')

# %%
df.head()
# Out:
#      Name                Teams Played In  Number of Maps Played  \
# 0   ZywOo              'Vitality', 'aAa'                    985
# 1  s1mple                'Natus Vincere'                   1544
# 2   sh1ro  'Gambit Youngsters', 'Gambit'                    853
# 3    deko                         '1WIN'                    382
# 4  saffee                'FURIA', 'paiN'                    374
#
#    Number of Rounds Played  Kill Death Difference  K/D Ratio  HLTV Rating
# 0                    25890                   5999       1.38         1.27
# 1                    40788                   8916       1.34         1.25
# 2                    22639                   5372       1.45         1.22
# 3                    10313                   2270       1.38         1.22
# 4                     9873                   1936       1.32         1.21

# %% [markdown]
# We currently have 7 columns in our dataset
#
# - Name <br>
# - Teams Played In <br>
# - Numbers of Maps Played <br>
# - Number of Rounds Played <br>
# - Kill Death Difference <br>
# - K/D Ratio <br>
# - HLTV Rating

# %% [markdown]
# New features can be created from the features we already have, we already know that :-<br>
# - KD Ratio is derived by ratio of total kills of player with total deaths of player <br>
# - Kill Death Difference is difference between kills and deaths

# %% [markdown]
# for simplicity lets say

# %% [markdown]
# ####  K = Total Kills of Player
# ####  D = Total Deaths of Player
# ####  KDD = Kill Death Difference
# ####  KDR = Kill Death Ratio

# %% [markdown]
# we know that

# %% [markdown]
# #### $KDR=\frac{K}{D}$

# %% [markdown]
# #### $K = KDR * D$

# %% [markdown]
# #### $KDD =  K - D $

# %% [markdown]
# we can use the above equations to compute total kills (kills) and total deaths (deaths) for each player

# %% [markdown]
# $K - D = KDD$

# %% [markdown]
# $K = KDD + D$

# %% [markdown]
# $KDR * D = KDD + D$

# %% [markdown]
# $(KDR * D) - D = KDD$

# %% [markdown]
# $D*(KDR - 1) = KDD$

# %% [markdown]
# $D = \frac{KDD}{KDR - 1}$

# %% [markdown]
# When Kill Death Difference(KDD) > 0 and KD Ratio > 1, it means that Kills > Deaths<br>
# Similarly when KIll Death Difference(KDD) < 0 and KD Ratio <1, it means that Deaths > Kills<br><br>
# But in case when KD Ratio = 1, it ideally means that Kills and Deaths are equal and there difference should be zero but that is not the case here, in dataset where the Kill Death Difference is not very large and KD Ratio should be very close to one instead the KD Ratio is rounded to 1<br>
# In such cases we cannot compute Total Kills and Total Deaths as we dont know the real value of KD Ratio<br>

# %%
df[df['K/D Ratio'] == 1]
# Out:
#            Name                                    Teams Played In  \
# 408        1962                               'Isurus', 'Leviatan'
# 417      dazzLe           'eUnited', 'Rise Nation', 'New Identity'
# 423       siuhy                          'MOUZ NXT', 'Izako Boars'
# 447     leo_drk                               'Sharks', '00NATION'
# 452    xiaosaGe                        '5POWER', 'Invictus', 'UYA'
# 456       Djoko                                'HEET', 'DBL PONEY'
# 460   KILLDREAM                      'AlienTech', 'k1ck', 'Giants'
# 462       RoLEX             'Signature', 'ZIGMA', 'Beyond', 'MiTH'
# 469       mopoz                                  'Movistar Riders'
# 471        pyth                                     'NIP', 'Vexed'
# 476  freakazoid               'Swole Patrol', 'Cloud9', 'Echo Fox'
# 486      Bååten  'x6tence Galaxy', 'Red Reserve', 'fnatic Acade...
# 488       xelos                   'Lemondogs', 'Epsilon', 'AliGon'
# 492     SEMPHIS                      'Splyce', 'TSM', 'Complexity'
# 497      robiin                                'Endpoint', 'DenDD'
# 503        VINI                                            'FURIA'
# 505     neptune             'Ghost', "Bee's Money Crew", 'Recon 5'
# 510     BARBARR         'Epsilon', 'x6tence Galaxy', 'Singularity'
# 521        krii                                   'EPG', 'Wolsung'
# 522        djay          'Party Astronauts', 'New England Whalers'
# 533       Lukki                    'Tricked', 'AGF', 'Singularity'
# 534         rmn                            'SAW', 'k1ck', 'Giants'
# 538       J1rah                               'ORDER', 'Breakaway'
# 544     stellar    'Party Astronauts', 'Vireo.pro', 'Divine', 'AA'
# 549     apocdud                      'VERTEX', 'Chiefs', 'Genuine'
# 556     DeadFox                                      'HellRaisers'
# 557  NickelBack                  'Entropiq', 'pro100', 'Winstrike'
# 558        isak                            'GamerLegion', 'Lilmix'
# 559       zende                                'DenDD', 'Property'
# 564      Llamas                  'Ground Zero', 'Breakaway', 'SYF'
# 588        mono                'x-kom', 'Illuminar', 'Izako Boars'
# 619      reltuC                                              'CLG'
#
#      Number of Maps Played  Number of Rounds Played  Kill Death Difference  \
# 408                    572                    14881                    -12
# 417                    690                    17971                     -8
# 423                    478                    12807                     43
# 447                    597                    15378                     31
# 452                    847                    22333                     35
# 456                    459                    12166                      5
# 460                    429                    11159                    -16
# 462                    492                    12610                     33
# 469                   1108                    29419                    -46
# 471                    756                    19801                     -5
# 476                    886                    22716                     43
# 486                    738                    19661                     39
# 488                    433                    11435                     28
# 492                    848                    21936                    -33
# 497                   1502                    40013                    -52
# 503                    975                    25398                     33
# 505                    498                    13218                    -23
# 510                    876                    23180                    -20
# 521                    398                    10522                      5
# 522                    827                    21378                    -33
# 533                    893                    23437                     -9
# 534                   1100                    28738                    -64
# 538                    782                    20288                    -14
# 544                    427                    10968                     26
# 549                    726                    18826                    -62
# 556                    807                    21060                    -54
# 557                   1355                    36025                    -33
# 558                    580                    15698                    -30
# 559                    397                    10444                     -1
# 564                    451                    11530                    -25
# 588                    662                    17680                    -17
# 619                    865                    22664                    -74
#
#      K/D Ratio  HLTV Rating
# 408        1.0         1.01
# 417        1.0         1.01
# 423        1.0         1.01
# 447        1.0         1.00
# 452        1.0         1.00
# 456        1.0         1.00
# 460        1.0         1.00
# 462        1.0         1.00
# 469        1.0         1.00
# 471        1.0         1.00
# 476        1.0         1.00
# 486        1.0         1.00
# 488        1.0         1.00
# 492        1.0         0.99
# 497        1.0         0.99
# 503        1.0         0.99
# 505        1.0         0.99
# 510        1.0         0.99
# 521        1.0         0.99
# 522        1.0         0.99
# 533        1.0         0.99
# 534        1.0         0.99
# 538        1.0         0.99
# 544        1.0         0.98
# 549        1.0         0.98
# 556        1.0         0.98
# 557        1.0         0.98
# 558        1.0         0.98
# 559        1.0         0.98
# 564        1.0         0.98
# 588        1.0         0.97
# 619        1.0         0.97

# %%
100 * len(df[df['K/D Ratio'] == 1])/len(df)
# Out:
# 3.9800995024875623

# %% [markdown]
# Around 4 % of Data has KD Ratio = 1 , for now we will assign them with Null Values in Total Kills and Total Deaths<br>
# We can also assign them average values or drop them if we wish but right now we will make them Null and for data with KD Ratio != 1 we already know the equation

# %%
def deaths(kdd,kdr):
    # kdd, kdr are arguments we get from dataframe
    '''
    function that computes Total Deaths(d) where,
    d -> Total Deaths
    kdd -> Kill Death Difference
    kdr -> KD Ratio
    '''
    # when kdr is not equal to 1 we compute d
    if kdr != 1:
        d = int(kdd/(kdr-1))
        
    # when kdr is 1 we assign Null value to d
    else:
        d = np.nan
    # we return d
    return d

# %% [markdown]
# we create a column __Total Deaths__ in dataset and compute its values by applying deaths function we created<br> df['Kill Death Difference'] and df['K/D Ratio'] are passed as arguments in deaths function to calculate __Total Deaths__

# %%
df['Total Deaths'] = df[['Kill Death Difference','K/D Ratio']].apply(lambda df: deaths(df['Kill Death Difference'],df['K/D Ratio']),axis=1)

# %% [markdown]
# we calculate __Total Kills__ by using Kill Death Difference and Total Deaths

# %%
df['Total Kills'] = df['Kill Death Difference'] + df['Total Deaths']

# %% [markdown]
# Hence we have added new columns __Total Deaths__ and __Total Kills__ to the Dataframe

# %%
df.head()
# Out:
#      Name                Teams Played In  Number of Maps Played  \
# 0   ZywOo              'Vitality', 'aAa'                    985
# 1  s1mple                'Natus Vincere'                   1544
# 2   sh1ro  'Gambit Youngsters', 'Gambit'                    853
# 3    deko                         '1WIN'                    382
# 4  saffee                'FURIA', 'paiN'                    374
#
#    Number of Rounds Played  Kill Death Difference  K/D Ratio  HLTV Rating  \
# 0                    25890                   5999       1.38         1.27
# 1                    40788                   8916       1.34         1.25
# 2                    22639                   5372       1.45         1.22
# 3                    10313                   2270       1.38         1.22
# 4                     9873                   1936       1.32         1.21
#
#    Total Deaths  Total Kills
# 0       15786.0      21785.0
# 1       26223.0      35139.0
# 2       11937.0      17309.0
# 3        5973.0       8243.0
# 4        6049.0       7985.0

# %% [markdown]
# Lets save the Dataframe to a csv file

# %%
df.to_csv('CSGO Player Dataset(FE).csv')
